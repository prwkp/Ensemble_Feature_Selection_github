# %%
import pandas as pd
import numpy as np
import math
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import statistics
import random

# Feature Selection
# Filter
from sklearn.feature_selection import mutual_info_classif as MIC
from sklearn.feature_selection import VarianceThreshold
from kydavra import MultiSURFSelector
# Wrapper
import shap
from sklearn.feature_selection import RFE
from boruta import BorutaPy

# model
import xgboost as xgb
from xgboost import XGBClassifier

# parameter tuning
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# evaluate
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score


from sklearn.feature_selection import SelectKBest

# from functools import reduce

# %%
# for threshold
def filter_arr(sample_arr, filter_index):
    result_val = sample_arr[filter_index]
    result_index = filter_index
    compare_index = filter_index + 1
    if sample_arr[0] == sample_arr[filter_index]:
        return (0,0)
        
    if (len(sample_arr) -1 == filter_index):
        compare_index = filter_index - 1
    
    if (sample_arr[filter_index] == sample_arr[compare_index]):
        for index, val in enumerate(sample_arr):
            if (val == result_val):
                result_val = sample_arr[index - 1]
                result_index = index - 1

    return (result_val, result_index)

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('LSVT_voice_rehabilitation_prepareddata.csv', header=0)
df
# Out:
#      Jitter->F0_abs_dif  Jitter->F0_dif_percent  \
# 0              0.088112                0.041697
# 1              0.161798                0.057364
# 2              0.554508                0.642913
# 3              0.031089                0.027108
# 4              0.076177                0.039071
# ..                  ...                     ...
# 121            0.116214                0.070546
# 122            0.700258                0.334397
# 123            0.072635                0.050743
# 124            0.111362                0.054237
# 125            0.256953                0.132694
#
#      Jitter->F0_PQ5_classical_Schoentgen  Jitter->F0_PQ5_classical_Baken  \
# 0                               0.000480                   -3.723300e-06
# 1                               0.000677                    5.466360e-06
# 2                               0.007576                   -7.443870e-07
# 3                               0.000314                   -2.214720e-07
# 4                               0.000302                    2.732110e-05
# ..                                   ...                             ...
# 121                             0.000837                    2.765070e-06
# 122                             0.003959                    8.297260e-06
# 123                             0.000597                   -5.277520e-06
# 124                             0.000646                   -1.546670e-06
# 125                             0.001576                    2.252400e-06
#
#      Jitter->F0_PQ5_generalised_Schoentgen  Jitter->F0_abs0th_perturb  \
# 0                                 0.000422                   2.458381
# 1                                 0.000206                   2.592066
# 2                                 0.006488                  12.691326
# 3                                 0.000216                   0.754288
# 4                                 0.001102                   1.270034
# ..                                     ...                        ...
# 121                               0.000333                   1.890006
# 122                               0.001516                   4.557797
# 123                               0.000434                   6.984651
# 124                               0.000277                   1.935398
# 125                               0.000708                   2.339807
#
#      Jitter->F0_CV  Jitter->F0_TKEO_mean  Jitter->F0_TKEO_std  \
# 0     6.332160e-07             47.021079          1366.430390
# 1     7.228520e-07             93.557936          2582.922776
# 2     6.946250e-04             52.988422           466.682635
# 3     1.868650e-07             13.982754           417.217249
# 4     4.918190e-05             56.373996          1608.317410
# ..             ...                   ...                  ...
# 121   9.844260e-07             34.083311           896.672947
# 122   1.581900e-05            104.648435          1583.166169
# 123   4.993260e-07             21.859427           625.288493
# 124   4.398080e-07             47.870508          1367.843467
# 125   3.050830e-06             52.103851          1124.445571
#
#      Jitter->F0_TKEO_prc5  ...  det_TKEO_std4_4_coef  det_TKEO_std4_5_coef  \
# 0               -7.103323  ...             54.335046            145.528630
# 1              -23.284761  ...             60.993338            163.560972
# 2              -45.308680  ...             38.641654            103.466808
# 3               -1.207741  ...             42.943275            115.014976
# 4               -3.491990  ...             52.715873            141.113865
# ..                    ...  ...                   ...                   ...
# 121            -10.446397  ...             50.085484            134.123291
# 122            -97.281717  ...             55.178858            147.584708
# 123             -4.116001  ...             46.893015            125.687344
# 124             -9.373059  ...             54.508453            146.094710
# 125            -38.918940  ...             52.318080            140.093685
#
#      det_TKEO_std4_6_coef  det_TKEO_std4_7_coef  det_TKEO_std4_8_coef  \
# 0              375.097397            921.296579           2137.079844
# 1              421.010306           1036.092589           2404.072562
# 2              264.654626            649.657090           1507.384591
# 3              296.320795            728.284936           1689.586636
# 4              363.511021            893.246151           2071.625622
# ..                    ...                   ...                   ...
# 121            345.396264            850.942761           1973.383824
# 122            379.897760            935.982559           2166.960428
# 123            323.728298            795.715774           1845.609006
# 124            376.377835            926.435019           2147.499571
# 125            360.725864            885.933217           2052.423390
#
#      det_TKEO_std4_9_coef  det_TKEO_std4_10_coef  Age  Gender  class
# 0             4697.131077            9931.208257   68       1      0
# 1             5284.082128           11165.095660   68       1      1
# 2             3315.804236            6974.600636   68       1      1
# 3             3713.818933            7851.139360   68       0      0
# 4             4554.204815            9623.566242   68       0      1
# ..                    ...                    ...  ...     ...    ...
# 121           4336.099395            9158.984652   63       0      1
# 122           4769.956102           10067.750440   63       0      1
# 123           4056.256338            8583.121863   69       0      0
# 124           4717.270683            9966.759379   69       0      1
# 125           4511.560376            9542.064446   69       0      1
#
# [126 rows x 313 columns]

# %%
col_names = list(df.columns[:-2])
features = df[col_names]
scaler = StandardScaler().fit(features.values)
features = scaler.transform(features.values)
df1 = pd.DataFrame(features, columns = col_names)
df1['Gender'] = df['Gender']
df1['class']  = df['class']

df1
# Out:
#      Jitter->F0_abs_dif  Jitter->F0_dif_percent  \
# 0             -0.399377               -0.431252
# 1             -0.185464               -0.343912
# 2              0.954598                2.920368
# 3             -0.564921               -0.512586
# 4             -0.434025               -0.445895
# ..                  ...                     ...
# 121           -0.317797               -0.270429
# 122            1.377720                1.200474
# 123           -0.444310               -0.380824
# 124           -0.331882               -0.361349
# 125            0.090779                0.076032
#
#      Jitter->F0_PQ5_classical_Schoentgen  Jitter->F0_PQ5_classical_Baken  \
# 0                              -0.427775                       -0.193157
# 1                              -0.334808                        0.393032
# 2                               2.925892                       -0.003139
# 3                              -0.506216                        0.030217
# 4                              -0.512084                        1.787099
# ..                                   ...                             ...
# 121                            -0.259019                        0.220722
# 122                             1.216387                        0.573609
# 123                            -0.372500                       -0.292298
# 124                            -0.349708                       -0.054315
# 125                             0.090292                        0.188020
#
#      Jitter->F0_PQ5_generalised_Schoentgen  Jitter->F0_abs0th_perturb  \
# 0                                -0.349789                  -0.185255
# 1                                -0.467868                  -0.179726
# 2                                 2.967826                   0.237966
# 3                                -0.462049                  -0.255734
# 4                                 0.022002                  -0.234403
# ..                                     ...                        ...
# 121                              -0.398413                  -0.208762
# 122                               0.248428                  -0.098426
# 123                              -0.343190                   0.001946
# 124                              -0.428717                  -0.206885
# 125                              -0.193157                  -0.190159
#
#      Jitter->F0_CV  Jitter->F0_TKEO_mean  Jitter->F0_TKEO_std  \
# 0        -0.190603             -0.330321            -0.264576
# 1        -0.190500              0.106770             0.484146
# 2         0.609078             -0.274274            -0.818349
# 3        -0.191117             -0.640630            -0.848794
# 4        -0.134661             -0.242475            -0.115700
# ..             ...                   ...                  ...
# 121      -0.190198             -0.451838            -0.553700
# 122      -0.173105              0.210936            -0.131180
# 123      -0.190757             -0.566649            -0.720731
# 124      -0.190826             -0.322343            -0.263706
# 125      -0.187817             -0.282582            -0.413512
#
#      Jitter->F0_TKEO_prc5  ...  det_TKEO_std4_4_coef  det_TKEO_std4_5_coef  \
# 0                0.330353  ...              0.085308              0.086062
# 1                0.164895  ...              0.953682              0.970554
# 2               -0.060302  ...             -1.961422             -1.977083
# 3                0.390636  ...             -1.400405             -1.410642
# 4                0.367279  ...             -0.125864             -0.130483
# ..                    ...  ...                   ...                   ...
# 121              0.296169  ...             -0.468919             -0.473373
# 122             -0.591733  ...              0.195358              0.186914
# 123              0.360899  ...             -0.885281             -0.887159
# 124              0.307144  ...              0.107924              0.113829
# 125              0.005034  ...             -0.177744             -0.180523
#
#      det_TKEO_std4_6_coef  det_TKEO_std4_7_coef  det_TKEO_std4_8_coef  \
# 0                0.086821              0.068374              0.070190
# 1                0.959255              0.960115              0.974571
# 2               -2.011804             -2.041734             -2.062769
# 3               -1.410086             -1.430949             -1.445598
# 4               -0.133342             -0.149523             -0.151522
# ..                    ...                   ...                   ...
# 121             -0.477558             -0.478137             -0.484295
# 122              0.178037              0.182456              0.171404
# 123             -0.889291             -0.907143             -0.917105
# 124              0.111152              0.108290              0.105485
# 125             -0.186266             -0.206330             -0.216566
#
#      det_TKEO_std4_9_coef  det_TKEO_std4_10_coef       Age  Gender  class
# 0                0.072930               0.086653  0.974953       1      0
# 1                0.974684               0.994152  0.974953       1      1
# 2               -2.049252              -2.087872  0.974953       1      1
# 3               -1.437768              -1.443196  0.974953       0      0
# 4               -0.146653              -0.139612  0.974953       0      1
# ..                    ...                    ...       ...     ...    ...
# 121             -0.481736              -0.481302  0.172050       0      1
# 122              0.184814               0.187077  0.172050       0      1
# 123             -0.911669              -0.904837  1.135533       0      0
# 124              0.103871               0.112800  1.135533       0      1
# 125             -0.212169              -0.199554  1.135533       0      1
#
# [126 rows x 313 columns]

# %%
# df1['class'] = df1.apply(lambda row: categorise(row), axis=1)
print('class 0 = ',df1['class'].value_counts()[0],'ตัว')
print('class 1 = ',df1['class'].value_counts()[1],'ตัว')
print('Majority Class= ', df1['class'].value_counts()[0]/len(df1))
# Out:
# class 0 =  42 ตัว
# class 1 =  84 ตัว
# Majority Class=  0.3333333333333333

# %%
# threshold:

log_2base = math.log(len(df1),2.0)
base2n = int(round(log_2base,0))
p2_5 = int(round(len(df1.columns)*0.025,0))
p5 =  int(round(len(df1.columns)*0.05,0))
p10 =  int(round(len(df1.columns)*0.1,0))
p20 =  int(round(len(df1.columns)*0.2,0))

print('treshold logbase2(n):', base2n)
print('treshold 2.5%:',p2_5)
print('treshold 5%:',p5)
print('treshold 10%:',p10)
print('treshold 20%:',p20)

thres_d = {'base2n':base2n,
              'p2_5':p2_5,
              'p5':p5,
              'p10':p10,
              'p20':p20}


thres_d
# Out:
# treshold logbase2(n): 7
# treshold 2.5%: 8
# treshold 5%: 16
# treshold 10%: 31
# treshold 20%: 63
# {'base2n': 7, 'p2_5': 8, 'p5': 16, 'p10': 31, 'p20': 63}

# %%
X_ = df1.drop(['class'], axis=1)
len(X_.columns)
# Out:
# 312

# %%
paramXGBoost_grid1 = {"subsample":[0.5, 0.75, 1],
              "colsample_bytree":[0.5, 0.75, 1],
              "max_depth":[5, 6, 7],
              "min_child_weight":[1,5,15],
              "learning_rate":[0.1, 0.01, 0.05],
              'eta': [0.01, 0.015, 0.02]
    }

# %%
paramXGBoost_grid2 = {"subsample":[0.2,0.6,0.9],
              "colsample_bytree":[0.5, 0.75, 1],
              "max_depth":[7,15,25],
              "min_child_weight":[0.1,0.5,1],
              "learning_rate":[0.1, 0.01, 0.05],
              'eta': [0.01, 0.015, 0.02]
    }

# %%
paramXGBoost_grid3 = {"subsample":[0.2,0.6,0.9],
              "colsample_bytree":[0.1,0.25, 0.5],
              "max_depth":[10,15,20],
              "min_child_weight":[20,40,60],
              "learning_rate":[0.1, 0.01, 0.05],
              'eta': [0.01, 0.015, 0.02]
    }

# %%
paramXGBoost_grid4 = {"subsample":[0.75,0.9,1],
              "colsample_bytree":[0.1,0.25, 0.5],
              "max_depth":[5,10,15],
              "min_child_weight":[5,10,20],
              "learning_rate":[0.1, 0.01, 0.05],
              'eta': [0.01, 0.015, 0.02]
    }

# %%
param_d = {'set1':paramXGBoost_grid1,
           'set2':paramXGBoost_grid2,
           'set3':paramXGBoost_grid3,
           'set4':paramXGBoost_grid4
          }

param_d
# Out:
# {'set1': {'subsample': [0.5, 0.75, 1],
#   'colsample_bytree': [0.5, 0.75, 1],
#   'max_depth': [5, 6, 7],
#   'min_child_weight': [1, 5, 15],
#   'learning_rate': [0.1, 0.01, 0.05],
#   'eta': [0.01, 0.015, 0.02]},
#  'set2': {'subsample': [0.2, 0.6, 0.9],
#   'colsample_bytree': [0.5, 0.75, 1],
#   'max_depth': [7, 15, 25],
#   'min_child_weight': [0.1, 0.5, 1],
#   'learning_rate': [0.1, 0.01, 0.05],
#   'eta': [0.01, 0.015, 0.02]},
#  'set3': {'subsample': [0.2, 0.6, 0.9],
#   'colsample_bytree': [0.1, 0.25, 0.5],
#   'max_depth': [10, 15, 20],
#   'min_child_weight': [20, 40, 60],
#   'learning_rate': [0.1, 0.01, 0.05],
#   'eta': [0.01, 0.015, 0.02]},
#  'set4': {'subsample': [0.75, 0.9, 1],
#   'colsample_bytree': [0.1, 0.25, 0.5],
#   'max_depth': [5, 10, 15],
#   'min_child_weight': [5, 10, 20],
#   'learning_rate': [0.1, 0.01, 0.05],
#   'eta': [0.01, 0.015, 0.02]}}

# %% [markdown]
# # XGBoost

# %%
# baseline model

X = df1.drop(['class'], axis=1)
y = df1['class']
 


# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123) 

""" do not need to split the data into training and test sets when using 
cross_val_score from the scikit-learn library. The purpose of 
cross_val_score is to perform cross-validation on the entire dataset, 
which automatically splits the data into training and validation sets 
for each fold. """
# XGBoost
xgbc = XGBClassifier(random_state=123)

## results F1 and stdF1 ##
avgF1_baselineXGBoost = cross_val_score(xgbc, X, y, scoring="f1", cv = 10).mean() ##<3## 
stdF1_baselineXGBoost = cross_val_score(xgbc, X, y, scoring="f1", cv = 10).std() ##<3##
print('Mean F1 Score: ', avgF1_baselineXGBoost)
print('std F1 Score: ', stdF1_baselineXGBoost)
# Out:
# Mean F1 Score:  0.8643578643578642
# std F1 Score:  0.04772011171804006

# %%
n_baselineXGBoost = len(X_.columns)
n_baselineXGBoost
# Out:
# 312

# %%
# tuned baseline model_ parameterset1 


# Instantiate the grid search model
grid_search = GridSearchCV(estimator = xgbc, param_grid = paramXGBoost_grid1,
                           cv = 5, n_jobs = -1, verbose = 2,scoring='f1')
# Fit the grid search to the data
grid_search.fit(X,y)

print(grid_search.best_params_)


xgbc_tuned1 = XGBClassifier(subsample=grid_search.best_params_['subsample'],
                                   max_depth=grid_search.best_params_['max_depth'],
                                   colsample_bytree=grid_search.best_params_['colsample_bytree'],
                                   min_child_weight=grid_search.best_params_['min_child_weight'],
                                   learning_rate=grid_search.best_params_['learning_rate'],
                                   eta=grid_search.best_params_['eta'])
xgbc_tuned1.fit(X,y)

print('\n')

## results F1 and stdF1 ##
avgF1set1_baselineXGBoost = cross_val_score(xgbc_tuned1, X, y, scoring="f1", cv = 10).mean() ##<3## 
stdF1set1_baselineXGBoost = cross_val_score(xgbc_tuned1, X, y, scoring="f1", cv = 10).std() ##<3##
print('Mean F1 Score: ', avgF1set1_baselineXGBoost)
print('std F1 Score: ', stdF1set1_baselineXGBoost)
# Out:
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# {'colsample_bytree': 1, 'eta': 0.01, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.75}
#
#
# Mean F1 Score:  0.9003102453102454
# std F1 Score:  0.05479680704989319

# %%
# tuned baseline model_ parameterset2


# Instantiate the grid search model
grid_search = GridSearchCV(estimator = xgbc, param_grid = paramXGBoost_grid2,
                           cv = 5, n_jobs = -1, verbose = 2,scoring='f1')
# Fit the grid search to the data
grid_search.fit(X,y)


print(grid_search.best_params_)


xgbc_tuned2 = XGBClassifier(subsample=grid_search.best_params_['subsample'],
                                   max_depth=grid_search.best_params_['max_depth'],
                                   colsample_bytree=grid_search.best_params_['colsample_bytree'],
                                   min_child_weight=grid_search.best_params_['min_child_weight'],
                                   learning_rate=grid_search.best_params_['learning_rate'],
                                   eta=grid_search.best_params_['eta'])
xgbc_tuned2.fit(X,y)

print('\n')

## results F1 and stdF1 ##
avgF1set2_baselineXGBoost = cross_val_score(xgbc_tuned2, X, y, scoring="f1", cv = 10).mean() ##<3## 
stdF1set2_baselineXGBoost = cross_val_score(xgbc_tuned2, X, y, scoring="f1", cv = 10).std() ##<3##
print('Mean F1 Score: ', avgF1set2_baselineXGBoost)
print('std F1 Score: ', stdF1set2_baselineXGBoost)
# Out:
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# {'colsample_bytree': 0.5, 'eta': 0.01, 'learning_rate': 0.1, 'max_depth': 7, 'min_child_weight': 0.5, 'subsample': 0.6}
#
#
# Mean F1 Score:  0.8961062303709362
# std F1 Score:  0.06205463659536259

# %%
# tuned baseline model_ parameterset3


# Instantiate the grid search model
grid_search = GridSearchCV(estimator = xgbc, param_grid = paramXGBoost_grid3,
                           cv = 5, n_jobs = -1, verbose = 2,scoring='f1')
# Fit the grid search to the data
grid_search.fit(X,y)


print(grid_search.best_params_)


xgbc_tuned3 = XGBClassifier(subsample=grid_search.best_params_['subsample'],
                                   max_depth=grid_search.best_params_['max_depth'],
                                   colsample_bytree=grid_search.best_params_['colsample_bytree'],
                                   min_child_weight=grid_search.best_params_['min_child_weight'],
                                   learning_rate=grid_search.best_params_['learning_rate'],
                                   eta=grid_search.best_params_['eta'])
xgbc_tuned3.fit(X,y)

print('\n')

## results F1 and stdF1 ##
avgF1set3_baselineXGBoost = cross_val_score(xgbc_tuned3, X, y, scoring="f1", cv = 10).mean() ##<3## 
stdF1set3_baselineXGBoost = cross_val_score(xgbc_tuned3, X, y, scoring="f1", cv = 10).std() ##<3##
print('Mean F1 Score: ', avgF1set3_baselineXGBoost)
print('std F1 Score: ', stdF1set3_baselineXGBoost)
# Out:
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# {'colsample_bytree': 0.1, 'eta': 0.01, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 20, 'subsample': 0.9}
#
#
# Mean F1 Score:  0.7996536796536796
# std F1 Score:  0.02055142088233746

# %%
# tuned baseline model_ parameterset4

# Instantiate the grid search model
grid_search = GridSearchCV(estimator = xgbc, param_grid = paramXGBoost_grid4,
                           cv = 5, n_jobs = -1, verbose = 2,scoring='f1')
# Fit the grid search to the data
grid_search.fit(X,y)


print(grid_search.best_params_)


xgbc_tuned4 = XGBClassifier(subsample=grid_search.best_params_['subsample'],
                                   max_depth=grid_search.best_params_['max_depth'],
                                   colsample_bytree=grid_search.best_params_['colsample_bytree'],
                                   min_child_weight=grid_search.best_params_['min_child_weight'],
                                   learning_rate=grid_search.best_params_['learning_rate'],
                                   eta=grid_search.best_params_['eta'])
xgbc_tuned4.fit(X,y)

## results F1 and stdF1 ##
avgF1set4_baselineXGBoost = cross_val_score(xgbc_tuned4, X, y, scoring="f1", cv = 10).mean() ##<3## 
stdF1set4_baselineXGBoost = cross_val_score(xgbc_tuned4, X, y, scoring="f1", cv = 10).std() ##<3##
print('Mean F1 Score: ', avgF1set4_baselineXGBoost)
print('std F1 Score: ', stdF1set4_baselineXGBoost)
# Out:
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# {'colsample_bytree': 0.1, 'eta': 0.01, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 5, 'subsample': 1}
# Mean F1 Score:  0.9017390289449114
# std F1 Score:  0.04974087795519576

# %%
output_basedlineXGBoost = {'n_baselineXGBoost':n_baselineXGBoost ,
                   'avgF1_baselineXGBoost':avgF1_baselineXGBoost ,
                   'stdF1_baselineXGBoost': stdF1_baselineXGBoost,
                   'avgF1set1_baselineXGBoost':avgF1set1_baselineXGBoost  ,
                   'stdF1set1_baselineXGBoost': stdF1set1_baselineXGBoost,
                   'avgF1set2_baselineXGBoost':avgF1set2_baselineXGBoost ,
                   'stdF1set2_baselineXGBoost':stdF1set2_baselineXGBoost ,
                   'avgF1set3_baselineXGBoost':avgF1set3_baselineXGBoost ,
                   'stdF1set3_baselineXGBoost':stdF1set3_baselineXGBoost ,
                   'avgF1set4_baselineXGBoost':avgF1set4_baselineXGBoost ,
                   'stdF1set4_baselineXGBoost':stdF1set4_baselineXGBoost ,
                     }
output_basedlineXGBoost
# Out:
# {'n_baselineXGBoost': 312,
#  'avgF1_baselineXGBoost': 0.8643578643578642,
#  'stdF1_baselineXGBoost': 0.04772011171804006,
#  'avgF1set1_baselineXGBoost': 0.9003102453102454,
#  'stdF1set1_baselineXGBoost': 0.05479680704989319,
#  'avgF1set2_baselineXGBoost': 0.8961062303709362,
#  'stdF1set2_baselineXGBoost': 0.06205463659536259,
#  'avgF1set3_baselineXGBoost': 0.7996536796536796,
#  'stdF1set3_baselineXGBoost': 0.02055142088233746,
#  'avgF1set4_baselineXGBoost': 0.9017390289449114,
#  'stdF1set4_baselineXGBoost': 0.04974087795519576}

# %%
output_basedlineXGBoost = pd.DataFrame([output_basedlineXGBoost])
output_basedlineXGBoost = output_basedlineXGBoost.transpose()
output_basedlineXGBoost.to_csv('output_basedlineXGBoost.csv', index=True)

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# # Filter

# %%
# Mutual Information: Filter method

mi_XGBoostscore = MIC(X,y)
mi_XGBoostfeatures = pd.DataFrame({'Feature':list(X_.columns),
                            'value_MI':mi_XGBoostscore})
mi_XGBoostfeatures['value_MI'] = mi_XGBoostfeatures['value_MI'].map('{:,.19f}'.format)
""" the more Mutual Information is the more feature importance it will have"""
mi_XGBoostfeatures = mi_XGBoostfeatures.sort_values(by='value_MI',ascending=False)
# mi_XGBoostfeatures = mi_XGBoostfeatures.set_index('Feature')
mi_XGBoostfeatures = mi_XGBoostfeatures.reset_index()
mi_XGBoostfeatures.to_csv('mi_XGBoostfeatures.csv', index=True)

mi_XGBoostfeatures
# Out:
#      index                 Feature               value_MI
# 0        0      Jitter->F0_abs_dif  0.2471220337085198171
# 1        9    Jitter->F0_TKEO_prc5  0.2159629565098533099
# 2       10   Jitter->F0_TKEO_prc25  0.2136084295259312871
# 3      143  entropy_shannon_5_coef  0.2070833897803643353
# 4      152      entropy_log_4_coef  0.2011992950764724952
# ..     ...                     ...                    ...
# 307     75           VFER->NSR_SEO  0.0000000000000000000
# 308    269   det_TKEO_std3_10_coef  0.0000000000000000000
# 309     74          VFER->NSR_TKEO  0.0000000000000000000
# 310     69           VFER->entropy  0.0000000000000000000
# 311    311                  Gender  0.0000000000000000000
#
# [312 rows x 3 columns]

# %%
# variance treshold: Filter method
"""Variance threshold is a simple method for feature selection that removes all features 
whose variance doesn't meet a certain threshold."""

threshold = 0.5
selector = VarianceThreshold(threshold)
selector = selector.fit(X)
variances = selector.variances_

variancethres_XGBoostfeatures = pd.DataFrame({'Feature':list(X_.columns),
                            'value_variancethres':variances})
# variancethres_XGBoostfeatures['value_variancethres'] = variancethres_XGBoostfeatures['value_variancethres'].map('{:,.19f}'.format)


"""The idea behind this method is that features 
with low variance don't contain much information and can be removed without affecting 
the performance of the model."""
variancethres_XGBoostfeatures = variancethres_XGBoostfeatures.sort_values(by='value_variancethres',ascending=False)
# variancethres_XGBoostfeatures = variancethres_XGBoostfeatures.set_index('Feature')
variancethres_XGBoostfeatures = variancethres_XGBoostfeatures.reset_index()
variancethres_XGBoostfeatures.to_csv('variancethres_XGBoostfeatures.csv', index=True)

variancethres_XGBoostfeatures
# Out:
#      index                 Feature  value_variancethres
# 0      219                     Ea2             1.000000
# 1      110  delta delta log energy             1.000000
# 2      161    det_TKEO_mean_3_coef             1.000000
# 3       72           VFER->SNR_SEO             1.000000
# 4      259  det_TKEO_mean3_10_coef             1.000000
# ..     ...                     ...                  ...
# 307    163    det_TKEO_mean_5_coef             1.000000
# 308    169     det_TKEO_std_1_coef             1.000000
# 309    226              Ed2_7_coef             1.000000
# 310    127             Data_length             1.000000
# 311    311                  Gender             0.244898
#
# [312 rows x 3 columns]

# %%
# MultiSURF: Filter method

features = list(X_.columns)

msrf = MultiSURFSelector(n_features=len(df1.columns)-1)
selected_cols = msrf.select(df1,'class')

list_of_numbers = list(range(1, len(df1.columns)))

MultiSURF_XGBoostfeatures = pd.DataFrame({'Feature':selected_cols,
                            'value_MultiSURF':list_of_numbers})
# # MultiSURF_XGBoostfeatures['value_MultiSURF'] = MultiSURF_XGBoostfeatures['value_MultiSURF'].map('{:,.19f}'.format)
# เรียงจากเลขน้อยคือสำคัญสูงสุด
MultiSURF_XGBoostfeatures = MultiSURF_XGBoostfeatures.sort_values(by='value_MultiSURF',ascending=True)
# MultiSURF_XGBoostfeatures = MultiSURF_XGBoostfeatures.set_index('Feature')
MultiSURF_XGBoostfeatures = MultiSURF_XGBoostfeatures.reset_index()

MultiSURF_XGBoostfeatures.to_csv('MultiSURF_XGBoostfeatures.csv', index=True)

MultiSURF_XGBoostfeatures
# Out:
#      index                  Feature  value_MultiSURF
# 0        0              Data_length                1
# 1        1   entropy_shannon_8_coef                2
# 2        2  entropy_shannon3_8_coef                3
# 3        3     det_TKEO_mean_7_coef                4
# 4        4   entropy_shannon_7_coef                5
# ..     ...                      ...              ...
# 307    307               10th delta              308
# 308    308            MFCC_8th coef              309
# 309    309                5th delta              310
# 310    310                4th delta              311
# 311    311                2nd delta              312
#
# [312 rows x 3 columns]

# %% [markdown]
# # Wrapper

# %%
# SHAP: Wrapper method


# Explain model predictions using shap library:
explainer = shap.TreeExplainer(xgbc_tuned4) #### 
shap_values = explainer.shap_values(X)
vals= np.abs(shap_values).mean(0)

SHAP_XGBoostfeatures= pd.DataFrame({'Feature':list(X_.columns),
                                 'value_SHAP':vals})
SHAP_XGBoostfeatures['value_SHAP'] = SHAP_XGBoostfeatures['value_SHAP'].map('{:,.19f}'.format)
SHAP_XGBoostfeatures = SHAP_XGBoostfeatures.sort_values(by=['value_SHAP'],ascending=False)
SHAP_XGBoostfeatures = SHAP_XGBoostfeatures.set_index('Feature')
SHAP_XGBoostfeatures.to_csv('SHAP_XGBoostfeatures.csv', index=True)

SHAP_XGBoostfeatures
# Out:
#                                                    value_SHAP
# Feature
# MFCC_2nd coef                           0.3918479681015014648
# GNE->NSR_SEO                            0.3068278729915618896
# Log energy                              0.2385229170322418213
# F0_series_F0_expTitze                   0.2027625888586044312
# Jitter->pitch_PQ5_classical_Schoentgen  0.1940937191247940063
# ...                                                       ...
# Ed_3_coef                               0.0000000000000000000
# Ed_4_coef                               0.0000000000000000000
# Ed_5_coef                               0.0000000000000000000
# Ed_6_coef                               0.0000000000000000000
# Gender                                  0.0000000000000000000
#
# [312 rows x 1 columns]

# %%
# Recursive Feature Elimination(RFE): Wrapper method


"""In this example, the parameter "n_features_to_select" is set to 1, 
which means that only one feature will be selected at each iteration 
of RFE"""

rfe = RFE(estimator=xgbc_tuned4, n_features_to_select=1) #### changehere
rfe.fit(X,y)

rfe_XGBoostfeatures = pd.DataFrame({'Feature':list(X_.columns),
                            'value_rfe':rfe.ranking_})

# rfe_XGBoostfeatures['value_XGBooste'] = rfe_XGBoostfeatures['value_XGBooste'].astype(int)
# rfe_XGBoostfeatures['value_XGBooste'] = rfe_XGBoostfeatures['value_XGBooste'].map('{:,.19f}'.format)
"""The RFE assigns a ranking value to each feature, typically starting from 1 for 
the most important feature, and increasing for the less important features."""
rfe_XGBoostfeatures = rfe_XGBoostfeatures.sort_values(by=['value_rfe'],ascending=True)
rfe_XGBoostfeatures = rfe_XGBoostfeatures.set_index('Feature')

rfe_XGBoostfeatures.to_csv('rfe_XGBoostfeatures.csv', index=True)

rfe_XGBoostfeatures
# Out:
#                                         value_rfe
# Feature
# entropy_log_4_coef                              1
# MFCC_2nd coef                                   2
# Jitter->pitch_PQ5_classical_Schoentgen          3
# entropy_shannon_5_coef                          4
# prc95_5_F0_series_F0_expTitze                   5
# ...                                           ...
# entropy_log_5_coef                            308
# entropy_log_7_coef                            309
# entropy_log_6_coef                            310
# Age                                           311
# Gender                                        312
#
# [312 rows x 1 columns]

# %%
# Boruta: Wrapper method




feat_selector = BorutaPy(xgbc_tuned4, n_estimators='auto', verbose=2, random_state=1) #### changehere
# feat_selector.fit(X_train, y_train)
feat_selector = feat_selector.fit(np.array(X), np.array(y)) 
features = X.columns
feature_importance = feat_selector.ranking_
# feature_importance
boruta_XGBoostfeatures = pd.DataFrame(list(zip(X_.columns, feature_importance[0:].tolist())), 
                                  columns=['Feature','value_boruta'])

# output the feature importance ranking: 1 is most importance >ascending=True
boruta_XGBoostfeatures = boruta_XGBoostfeatures.sort_values(by=['value_boruta'],ascending=True)
boruta_XGBoostfeatures = boruta_XGBoostfeatures.set_index('Feature')

boruta_XGBoostfeatures.to_csv('boruta_XGBoostfeatures.csv', index=True)

boruta_XGBoostfeatures
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	312
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	312
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	312
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	312
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	312
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	312
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	312
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	62
# Rejected: 	250
# Iteration: 	9 / 100
# Confirmed: 	0
# Tentative: 	62
# Rejected: 	250
# Iteration: 	10 / 100
# Confirmed: 	0
# Tentative: 	62
# Rejected: 	250
# Iteration: 	11 / 100
# Confirmed: 	0
# Tentative: 	62
# Rejected: 	250
# Iteration: 	12 / 100
# Confirmed: 	0
# Tentative: 	53
# Rejected: 	259
# Iteration: 	13 / 100
# Confirmed: 	0
# Tentative: 	53
# Rejected: 	259
# Iteration: 	14 / 100
# Confirmed: 	0
# Tentative: 	53
# Rejected: 	259
# Iteration: 	15 / 100
# Confirmed: 	0
# Tentative: 	53
# Rejected: 	259
# Iteration: 	16 / 100
# Confirmed: 	0
# Tentative: 	53
# Rejected: 	259
# Iteration: 	17 / 100
# Confirmed: 	0
# Tentative: 	51
# Rejected: 	261
# Iteration: 	18 / 100
# Confirmed: 	1
# Tentative: 	50
# Rejected: 	261
# Iteration: 	19 / 100
# Confirmed: 	4
# Tentative: 	47
# Rejected: 	261
# Iteration: 	20 / 100
# Confirmed: 	4
# Tentative: 	47
# Rejected: 	261
# Iteration: 	21 / 100
# Confirmed: 	4
# Tentative: 	47
# Rejected: 	261
# Iteration: 	22 / 100
# Confirmed: 	4
# Tentative: 	40
# Rejected: 	268
# Iteration: 	23 / 100
# Confirmed: 	4
# Tentative: 	40
# Rejected: 	268
# Iteration: 	24 / 100
# Confirmed: 	4
# Tentative: 	40
# Rejected: 	268
# Iteration: 	25 / 100
# Confirmed: 	4
# Tentative: 	40
# Rejected: 	268
# Iteration: 	26 / 100
# Confirmed: 	4
# Tentative: 	39
# Rejected: 	269
# Iteration: 	27 / 100
# Confirmed: 	4
# Tentative: 	39
# Rejected: 	269
# Iteration: 	28 / 100
# Confirmed: 	4
# Tentative: 	39
# Rejected: 	269
# Iteration: 	29 / 100
# Confirmed: 	6
# Tentative: 	33
# Rejected: 	273
# Iteration: 	30 / 100
# Confirmed: 	6
# Tentative: 	33
# Rejected: 	273
# Iteration: 	31 / 100
# Confirmed: 	6
# Tentative: 	33
# Rejected: 	273
# Iteration: 	32 / 100
# Confirmed: 	6
# Tentative: 	30
# Rejected: 	276
# Iteration: 	33 / 100
# Confirmed: 	6
# Tentative: 	30
# Rejected: 	276
# Iteration: 	34 / 100
# Confirmed: 	7
# Tentative: 	29
# Rejected: 	276
# Iteration: 	35 / 100
# Confirmed: 	7
# Tentative: 	29
# Rejected: 	276
# Iteration: 	36 / 100
# Confirmed: 	7
# Tentative: 	29
# Rejected: 	276
# Iteration: 	37 / 100
# Confirmed: 	8
# Tentative: 	28
# Rejected: 	276
# Iteration: 	38 / 100
# Confirmed: 	8
# Tentative: 	28
# Rejected: 	276
# Iteration: 	39 / 100
# Confirmed: 	8
# Tentative: 	28
# Rejected: 	276
# Iteration: 	40 / 100
# Confirmed: 	8
# Tentative: 	28
# Rejected: 	276
# Iteration: 	41 / 100
# Confirmed: 	8
# Tentative: 	28
# Rejected: 	276
# Iteration: 	42 / 100
# Confirmed: 	8
# Tentative: 	28
# Rejected: 	276
# Iteration: 	43 / 100
# Confirmed: 	8
# Tentative: 	28
# Rejected: 	276
# Iteration: 	44 / 100
# Confirmed: 	8
# Tentative: 	28
# Rejected: 	276
# Iteration: 	45 / 100
# Confirmed: 	8
# Tentative: 	28
# Rejected: 	276
# Iteration: 	46 / 100
# Confirmed: 	9
# Tentative: 	27
# Rejected: 	276
# Iteration: 	47 / 100
# Confirmed: 	9
# Tentative: 	27
# Rejected: 	276
# Iteration: 	48 / 100
# Confirmed: 	9
# Tentative: 	27
# Rejected: 	276
# Iteration: 	49 / 100
# Confirmed: 	9
# Tentative: 	27
# Rejected: 	276
# Iteration: 	50 / 100
# Confirmed: 	9
# Tentative: 	27
# Rejected: 	276
# Iteration: 	51 / 100
# Confirmed: 	9
# Tentative: 	27
# Rejected: 	276
# Iteration: 	52 / 100
# Confirmed: 	9
# Tentative: 	27
# Rejected: 	276
# Iteration: 	53 / 100
# Confirmed: 	9
# Tentative: 	27
# Rejected: 	276
# Iteration: 	54 / 100
# Confirmed: 	9
# Tentative: 	26
# Rejected: 	277
# Iteration: 	55 / 100
# Confirmed: 	9
# Tentative: 	26
# Rejected: 	277
# Iteration: 	56 / 100
# Confirmed: 	9
# Tentative: 	26
# Rejected: 	277
# Iteration: 	57 / 100
# Confirmed: 	9
# Tentative: 	26
# Rejected: 	277
# Iteration: 	58 / 100
# Confirmed: 	9
# Tentative: 	26
# Rejected: 	277
# Iteration: 	59 / 100
# Confirmed: 	9
# Tentative: 	26
# Rejected: 	277
# Iteration: 	60 / 100
# Confirmed: 	9
# Tentative: 	26
# Rejected: 	277
# Iteration: 	61 / 100
# Confirmed: 	9
# Tentative: 	26
# Rejected: 	277
# Iteration: 	62 / 100
# Confirmed: 	9
# Tentative: 	26
# Rejected: 	277
# Iteration: 	63 / 100
# Confirmed: 	9
# Tentative: 	26
# Rejected: 	277
# Iteration: 	64 / 100
# Confirmed: 	9
# Tentative: 	26
# Rejected: 	277
# Iteration: 	65 / 100
# Confirmed: 	9
# Tentative: 	26
# Rejected: 	277
# Iteration: 	66 / 100
# Confirmed: 	9
# Tentative: 	26
# Rejected: 	277
# Iteration: 	67 / 100
# Confirmed: 	10
# Tentative: 	25
# Rejected: 	277
# Iteration: 	68 / 100
# Confirmed: 	10
# Tentative: 	25
# Rejected: 	277
# Iteration: 	69 / 100
# Confirmed: 	10
# Tentative: 	25
# Rejected: 	277
# Iteration: 	70 / 100
# Confirmed: 	10
# Tentative: 	25
# Rejected: 	277
# Iteration: 	71 / 100
# Confirmed: 	10
# Tentative: 	25
# Rejected: 	277
# Iteration: 	72 / 100
# Confirmed: 	10
# Tentative: 	25
# Rejected: 	277
# Iteration: 	73 / 100
# Confirmed: 	10
# Tentative: 	25
# Rejected: 	277
# Iteration: 	74 / 100
# Confirmed: 	10
# Tentative: 	25
# Rejected: 	277
# Iteration: 	75 / 100
# Confirmed: 	10
# Tentative: 	25
# Rejected: 	277
# Iteration: 	76 / 100
# Confirmed: 	10
# Tentative: 	25
# Rejected: 	277
# Iteration: 	77 / 100
# Confirmed: 	10
# Tentative: 	25
# Rejected: 	277
# Iteration: 	78 / 100
# Confirmed: 	10
# Tentative: 	25
# Rejected: 	277
# Iteration: 	79 / 100
# Confirmed: 	10
# Tentative: 	25
# Rejected: 	277
# Iteration: 	80 / 100
# Confirmed: 	10
# Tentative: 	25
# Rejected: 	277
# Iteration: 	81 / 100
# Confirmed: 	10
# Tentative: 	25
# Rejected: 	277
# Iteration: 	82 / 100
# Confirmed: 	10
# Tentative: 	25
# Rejected: 	277
# Iteration: 	83 / 100
# Confirmed: 	11
# Tentative: 	24
# Rejected: 	277
# Iteration: 	84 / 100
# Confirmed: 	11
# Tentative: 	24
# Rejected: 	277
# Iteration: 	85 / 100
# Confirmed: 	11
# Tentative: 	24
# Rejected: 	277
# Iteration: 	86 / 100
# Confirmed: 	11
# Tentative: 	24
# Rejected: 	277
# Iteration: 	87 / 100
# Confirmed: 	11
# Tentative: 	24
# Rejected: 	277
# Iteration: 	88 / 100
# Confirmed: 	11
# Tentative: 	24
# Rejected: 	277
# Iteration: 	89 / 100
# Confirmed: 	11
# Tentative: 	24
# Rejected: 	277
# Iteration: 	90 / 100
# Confirmed: 	12
# Tentative: 	23
# Rejected: 	277
# Iteration: 	91 / 100
# Confirmed: 	12
# Tentative: 	23
# Rejected: 	277
# Iteration: 	92 / 100
# Confirmed: 	12
# Tentative: 	23
# Rejected: 	277
# Iteration: 	93 / 100
# Confirmed: 	12
# Tentative: 	23
# Rejected: 	277
# Iteration: 	94 / 100
# Confirmed: 	12
# Tentative: 	23
# Rejected: 	277
# Iteration: 	95 / 100
# Confirmed: 	12
# Tentative: 	23
# Rejected: 	277
# Iteration: 	96 / 100
# Confirmed: 	12
# Tentative: 	23
# Rejected: 	277
# Iteration: 	97 / 100
# Confirmed: 	12
# Tentative: 	23
# Rejected: 	277
# Iteration: 	98 / 100
# Confirmed: 	12
# Tentative: 	23
# Rejected: 	277
# Iteration: 	99 / 100
# Confirmed: 	12
# Tentative: 	23
# Rejected: 	277
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	12
# Tentative: 	12
# Rejected: 	277
#                            value_boruta
# Feature
# Jitter->F0_abs_dif                    1
# entropy_log_4_coef                    1
# std_F0_series_F0_expTitze             1
# det_TKEO_mean_8_coef                  1
# DFA                                   1
# ...                                 ...
# entropy_shannon_4_coef              189
# entropy_shannon_6_coef              189
# entropy_log_1_coef                  189
# 6th delta                           189
# Gender                              189
#
# [312 rows x 1 columns]

# %% [markdown]
# # single FS

# %% [markdown]
# # Filter

# %%
method_Filter = {'MI': mi_XGBoostfeatures,
          'variancethres': variancethres_XGBoostfeatures,
          'MultiSURF': MultiSURF_XGBoostfeatures
         }

# %%
output_filter = dict()


for tres,t in thres_d.items():
    for met,m in method_Filter.items():
        k =(filter_arr(m.filter(regex='value').squeeze(), t-1))   
        if k[1] != 0:
            n = k[1]+1 
            print("n"+"_single"+met+"_"+tres+"XGBoost",n)
            output_filter["n"+"_single"+met+"_"+tres+"XGBoost"] = n
            df_selected = m.iloc[:k[1]+1]
            df_filter = df1.filter(items=df_selected['Feature'])
            X = df_filter
            y = df1['class']
            
            ## before tuned ##
            xgbc = XGBClassifier(random_state=123)
            xgbc.fit(X,y)
            ## results F1 and stdF1 ##
            m = cross_val_score(xgbc, X, y, scoring="f1", cv = 10).mean() 
            s = cross_val_score(xgbc, X, y, scoring="f1", cv = 10).std() 
            print("avgF1"+"_single"+met+"_"+tres+"XGBoost" , m)
            print("stdF1"+"_single"+met+"_"+tres+"XGBoost",s)
            output_filter["avgF1"+"_single"+met+"_"+tres+"XGBoost"] = m
            output_filter["stdF1"+"_single"+met+"_"+tres+"XGBoost"] = s
            
            for parm, p in param_d.items():
                # Instantiate the grid search model
                grid_search = GridSearchCV(estimator = xgbc, param_grid = p,
                                        cv = 5, n_jobs = -1, verbose = 2,scoring='f1')
                # Fit the grid search to the data
                grid_search.fit(X,y)
        #         print(grid_search.best_params_)
                xgbc_tuned = XGBClassifier(subsample=grid_search.best_params_['subsample'],
                                                max_depth=grid_search.best_params_['max_depth'],
                                                colsample_bytree=grid_search.best_params_['colsample_bytree'],
                                                min_child_weight=grid_search.best_params_['min_child_weight'],
                                                learning_rate=grid_search.best_params_['learning_rate'],
                                                eta=grid_search.best_params_['eta'])
                xgbc_tuned.fit(X,y)

                ## results F1 and stdF1 ##
                m_tune  = cross_val_score(xgbc_tuned, X, y, scoring="f1", cv = 10).mean() 
                s_tune  = cross_val_score(xgbc_tuned, X, y, scoring="f1", cv = 10).std() 
                print("avgF1"+parm+"_single"+met+"_"+tres+"XGBoost" , m_tune)
                print("stdF1"+parm+"_single"+met+"_"+tres+"XGBoost",s_tune)
                output_filter["avgF1"+parm+"_single"+met+"_"+tres+"XGBoost"] = m_tune
                output_filter["stdF1"+parm+"_single"+met+"_"+tres+"XGBoost"] = s_tune

        else:
            output_filter["n"+"_single"+met+"_"+tres+"XGBoost"] = k[1]
            output_filter["avgF1"+"_single"+met+"_"+tres+"XGBoost"] = k[1]
            output_filter["stdF1"+"_single"+met+"_"+tres+"XGBoost"] = k[1]
            for parm, p in param_d.items():
                output_filter["avgF1"+parm+"_single"+met+"_"+tres+"XGBoost"] = k[1]
                output_filter["stdF1"+parm+"_single"+met+"_"+tres+"XGBoost"] = k[1]
# Out:
# n_singleMI_base2nXGBoost 7
# avgF1_singleMI_base2nXGBoost 0.7720696443219662
# stdF1_singleMI_base2nXGBoost 0.13859793622453048
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleMI_base2nXGBoost 0.8276521053765634
# stdF1set1_singleMI_base2nXGBoost 0.11723963541498901
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleMI_base2nXGBoost 0.8368250377073906
# stdF1set2_singleMI_base2nXGBoost 0.11536066772061342
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleMI_base2nXGBoost 0.7996536796536796
# stdF1set3_singleMI_base2nXGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleMI_base2nXGBoost 0.8489923337756153
# stdF1set4_singleMI_base2nXGBoost 0.1287265356043338
# n_singlevariancethres_base2nXGBoost 3
# avgF1_singlevariancethres_base2nXGBoost 0.8139094058676102
# stdF1_singlevariancethres_base2nXGBoost 0.07767029649821591
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singlevariancethres_base2nXGBoost 0.8442378338895367
# stdF1set1_singlevariancethres_base2nXGBoost 0.046392444546284016
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singlevariancethres_base2nXGBoost 0.8379108645052918
# stdF1set2_singlevariancethres_base2nXGBoost 0.07041073603086961
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singlevariancethres_base2nXGBoost 0.7996536796536796
# stdF1set3_singlevariancethres_base2nXGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singlevariancethres_base2nXGBoost 0.7530038898150353
# stdF1set4_singlevariancethres_base2nXGBoost 0.10606435113452926
# n_singleMultiSURF_base2nXGBoost 7
# avgF1_singleMultiSURF_base2nXGBoost 0.7726963241436925
# stdF1_singleMultiSURF_base2nXGBoost 0.06436807872082623
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleMultiSURF_base2nXGBoost 0.812770428745661
# stdF1set1_singleMultiSURF_base2nXGBoost 0.1117901888096558
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleMultiSURF_base2nXGBoost 0.7739815318840086
# stdF1set2_singleMultiSURF_base2nXGBoost 0.09206764188293871
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleMultiSURF_base2nXGBoost 0.7996536796536796
# stdF1set3_singleMultiSURF_base2nXGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleMultiSURF_base2nXGBoost 0.8136068205959848
# stdF1set4_singleMultiSURF_base2nXGBoost 0.05770481902331948
# n_singleMI_p2_5XGBoost 8
# avgF1_singleMI_p2_5XGBoost 0.8173962295014926
# stdF1_singleMI_p2_5XGBoost 0.11964806947912665
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleMI_p2_5XGBoost 0.8124622926093513
# stdF1set1_singleMI_p2_5XGBoost 0.13801240965711237
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleMI_p2_5XGBoost 0.8245561301443655
# stdF1set2_singleMI_p2_5XGBoost 0.11997370002779371
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleMI_p2_5XGBoost 0.7996536796536796
# stdF1set3_singleMI_p2_5XGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleMI_p2_5XGBoost 0.8405365223012282
# stdF1set4_singleMI_p2_5XGBoost 0.13520337708054253
# n_singlevariancethres_p2_5XGBoost 3
# avgF1_singlevariancethres_p2_5XGBoost 0.8139094058676102
# stdF1_singlevariancethres_p2_5XGBoost 0.07767029649821591
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singlevariancethres_p2_5XGBoost 0.8442378338895367
# stdF1set1_singlevariancethres_p2_5XGBoost 0.046392444546284016
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singlevariancethres_p2_5XGBoost 0.8379108645052918
# stdF1set2_singlevariancethres_p2_5XGBoost 0.07041073603086961
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singlevariancethres_p2_5XGBoost 0.7996536796536796
# stdF1set3_singlevariancethres_p2_5XGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singlevariancethres_p2_5XGBoost 0.7530038898150353
# stdF1set4_singlevariancethres_p2_5XGBoost 0.10606435113452926
# n_singleMultiSURF_p2_5XGBoost 8
# avgF1_singleMultiSURF_p2_5XGBoost 0.8247795161494851
# stdF1_singleMultiSURF_p2_5XGBoost 0.05946904321894572
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleMultiSURF_p2_5XGBoost 0.8531203437085791
# stdF1set1_singleMultiSURF_p2_5XGBoost 0.07586466062966668
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleMultiSURF_p2_5XGBoost 0.8596562914209974
# stdF1set2_singleMultiSURF_p2_5XGBoost 0.07584922331214687
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleMultiSURF_p2_5XGBoost 0.7996536796536796
# stdF1set3_singleMultiSURF_p2_5XGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleMultiSURF_p2_5XGBoost 0.840893665158371
# stdF1set4_singleMultiSURF_p2_5XGBoost 0.07517053653739426
# n_singleMI_p5XGBoost 16
# avgF1_singleMI_p5XGBoost 0.8829099804564201
# stdF1_singleMI_p5XGBoost 0.04915086654011707
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleMI_p5XGBoost 0.8976213818860878
# stdF1set1_singleMI_p5XGBoost 0.04797886164012967
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleMI_p5XGBoost 0.8910854341736695
# stdF1set2_singleMI_p5XGBoost 0.052920590624400646
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleMI_p5XGBoost 0.7996536796536796
# stdF1set3_singleMI_p5XGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleMI_p5XGBoost 0.8891079508726568
# stdF1set4_singleMI_p5XGBoost 0.07840092548513558
# n_singlevariancethres_p5XGBoost 3
# avgF1_singlevariancethres_p5XGBoost 0.8139094058676102
# stdF1_singlevariancethres_p5XGBoost 0.07767029649821591
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singlevariancethres_p5XGBoost 0.8442378338895367
# stdF1set1_singlevariancethres_p5XGBoost 0.046392444546284016
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singlevariancethres_p5XGBoost 0.8379108645052918
# stdF1set2_singlevariancethres_p5XGBoost 0.07041073603086961
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singlevariancethres_p5XGBoost 0.7996536796536796
# stdF1set3_singlevariancethres_p5XGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singlevariancethres_p5XGBoost 0.7530038898150353
# stdF1set4_singlevariancethres_p5XGBoost 0.10606435113452926
# n_singleMultiSURF_p5XGBoost 16
# avgF1_singleMultiSURF_p5XGBoost 0.843314422935166
# stdF1_singleMultiSURF_p5XGBoost 0.059078130836167225
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleMultiSURF_p5XGBoost 0.876109769143825
# stdF1set1_singleMultiSURF_p5XGBoost 0.0801557078886233
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleMultiSURF_p5XGBoost 0.8561807800043095
# stdF1set2_singleMultiSURF_p5XGBoost 0.06775258788354803
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleMultiSURF_p5XGBoost 0.7996536796536796
# stdF1set3_singleMultiSURF_p5XGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleMultiSURF_p5XGBoost 0.8841656838173867
# stdF1set4_singleMultiSURF_p5XGBoost 0.06217591537574651
# n_singleMI_p10XGBoost 31
# avgF1_singleMI_p10XGBoost 0.8849340691987753
# stdF1_singleMI_p10XGBoost 0.0639748422267118
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleMI_p10XGBoost 0.8810854341736694
# stdF1set1_singleMI_p10XGBoost 0.05934894772031591
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleMI_p10XGBoost 0.9043650793650795
# stdF1set2_singleMI_p10XGBoost 0.052729719138482824
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleMI_p10XGBoost 0.7996536796536796
# stdF1set3_singleMI_p10XGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleMI_p10XGBoost 0.8990873015873018
# stdF1set4_singleMI_p10XGBoost 0.04312309091446992
# n_singlevariancethres_p10XGBoost 3
# avgF1_singlevariancethres_p10XGBoost 0.8139094058676102
# stdF1_singlevariancethres_p10XGBoost 0.07767029649821591
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singlevariancethres_p10XGBoost 0.8442378338895367
# stdF1set1_singlevariancethres_p10XGBoost 0.046392444546284016
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singlevariancethres_p10XGBoost 0.8379108645052918
# stdF1set2_singlevariancethres_p10XGBoost 0.07041073603086961
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singlevariancethres_p10XGBoost 0.7996536796536796
# stdF1set3_singlevariancethres_p10XGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singlevariancethres_p10XGBoost 0.7530038898150353
# stdF1set4_singlevariancethres_p10XGBoost 0.10606435113452926
# n_singleMultiSURF_p10XGBoost 31
# avgF1_singleMultiSURF_p10XGBoost 0.841358666273527
# stdF1_singleMultiSURF_p10XGBoost 0.07039779517394382
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleMultiSURF_p10XGBoost 0.8836969875669567
# stdF1set1_singleMultiSURF_p10XGBoost 0.06364135854542131
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleMultiSURF_p10XGBoost 0.8556435540723466
# stdF1set2_singleMultiSURF_p10XGBoost 0.04912067165729662
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleMultiSURF_p10XGBoost 0.7996536796536796
# stdF1set3_singleMultiSURF_p10XGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleMultiSURF_p10XGBoost 0.8497750598214996
# stdF1set4_singleMultiSURF_p10XGBoost 0.07468379559357011
# n_singleMI_p20XGBoost 63
# avgF1_singleMI_p20XGBoost 0.8596301230589155
# stdF1_singleMI_p20XGBoost 0.045295527101393285
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleMI_p20XGBoost 0.8727453532020094
# stdF1set1_singleMI_p20XGBoost 0.055422725724415096
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleMI_p20XGBoost 0.88921802054155
# stdF1set2_singleMI_p20XGBoost 0.046962764013093114
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleMI_p20XGBoost 0.7996536796536796
# stdF1set3_singleMI_p20XGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleMI_p20XGBoost 0.8883026287438053
# stdF1set4_singleMI_p20XGBoost 0.08083154644190214
# n_singlevariancethres_p20XGBoost 37
# avgF1_singlevariancethres_p20XGBoost 0.86422096908939
# stdF1_singlevariancethres_p20XGBoost 0.0621180530796776
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singlevariancethres_p20XGBoost 0.8627550493881764
# stdF1set1_singlevariancethres_p20XGBoost 0.06479814985969269
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singlevariancethres_p20XGBoost 0.8502049240748931
# stdF1set2_singlevariancethres_p20XGBoost 0.08442805409399907
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singlevariancethres_p20XGBoost 0.7996536796536796
# stdF1set3_singlevariancethres_p20XGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singlevariancethres_p20XGBoost 0.8605695611577964
# stdF1set4_singlevariancethres_p20XGBoost 0.039132855700745546
# n_singleMultiSURF_p20XGBoost 63
# avgF1_singleMultiSURF_p20XGBoost 0.8221908939014202
# stdF1_singleMultiSURF_p20XGBoost 0.09256925359852387
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleMultiSURF_p20XGBoost 0.8254351659692217
# stdF1set1_singleMultiSURF_p20XGBoost 0.05403326710301302
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleMultiSURF_p20XGBoost 0.8516311612364242
# stdF1set2_singleMultiSURF_p20XGBoost 0.07670624002160999
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleMultiSURF_p20XGBoost 0.7996536796536796
# stdF1set3_singleMultiSURF_p20XGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleMultiSURF_p20XGBoost 0.85438453359506
# stdF1set4_singleMultiSURF_p20XGBoost 0.07309259049170103

# %%
output_filter
# Out:
# {'n_singleMI_base2nXGBoost': 7,
#  'avgF1_singleMI_base2nXGBoost': 0.7720696443219662,
#  'stdF1_singleMI_base2nXGBoost': 0.13859793622453048,
#  'avgF1set1_singleMI_base2nXGBoost': 0.8276521053765634,
#  'stdF1set1_singleMI_base2nXGBoost': 0.11723963541498901,
#  'avgF1set2_singleMI_base2nXGBoost': 0.8368250377073906,
#  'stdF1set2_singleMI_base2nXGBoost': 0.11536066772061342,
#  'avgF1set3_singleMI_base2nXGBoost': 0.7996536796536796,
#  'stdF1set3_singleMI_base2nXGBoost': 0.02055142088233746,
#  'avgF1set4_singleMI_base2nXGBoost': 0.8489923337756153,
#  'stdF1set4_singleMI_base2nXGBoost': 0.1287265356043338,
#  'n_singlevariancethres_base2nXGBoost': 3,
#  'avgF1_singlevariancethres_base2nXGBoost': 0.8139094058676102,
#  'stdF1_singlevariancethres_base2nXGBoost': 0.07767029649821591,
#  'avgF1set1_singlevariancethres_base2nXGBoost': 0.8442378338895367,
#  'stdF1set1_singlevariancethres_base2nXGBoost': 0.046392444546284016,
#  'avgF1set2_singlevariancethres_base2nXGBoost': 0.8379108645052918,
#  'stdF1set2_singlevariancethres_base2nXGBoost': 0.07041073603086961,
#  'avgF1set3_singlevariancethres_base2nXGBoost': 0.7996536796536796,
#  'stdF1set3_singlevariancethres_base2nXGBoost': 0.02055142088233746,
#  'avgF1set4_singlevariancethres_base2nXGBoost': 0.7530038898150353,
#  'stdF1set4_singlevariancethres_base2nXGBoost': 0.10606435113452926,
#  'n_singleMultiSURF_base2nXGBoost': 7,
#  'avgF1_singleMultiSURF_base2nXGBoost': 0.7726963241436925,
#  'stdF1_singleMultiSURF_base2nXGBoost': 0.06436807872082623,
#  'avgF1set1_singleMultiSURF_base2nXGBoost': 0.812770428745661,
#  'stdF1set1_singleMultiSURF_base2nXGBoost': 0.1117901888096558,
#  'avgF1set2_singleMultiSURF_base2nXGBoost': 0.7739815318840086,
#  'stdF1set2_singleMultiSURF_base2nXGBoost': 0.09206764188293871,
#  'avgF1set3_singleMultiSURF_base2nXGBoost': 0.7996536796536796,
#  'stdF1set3_singleMultiSURF_base2nXGBoost': 0.02055142088233746,
#  'avgF1set4_singleMultiSURF_base2nXGBoost': 0.8136068205959848,
#  'stdF1set4_singleMultiSURF_base2nXGBoost': 0.05770481902331948,
#  'n_singleMI_p2_5XGBoost': 8,
#  'avgF1_singleMI_p2_5XGBoost': 0.8173962295014926,
#  'stdF1_singleMI_p2_5XGBoost': 0.11964806947912665,
#  'avgF1set1_singleMI_p2_5XGBoost': 0.8124622926093513,
#  'stdF1set1_singleMI_p2_5XGBoost': 0.13801240965711237,
#  'avgF1set2_singleMI_p2_5XGBoost': 0.8245561301443655,
#  'stdF1set2_singleMI_p2_5XGBoost': 0.11997370002779371,
#  'avgF1set3_singleMI_p2_5XGBoost': 0.7996536796536796,
#  'stdF1set3_singleMI_p2_5XGBoost': 0.02055142088233746,
#  'avgF1set4_singleMI_p2_5XGBoost': 0.8405365223012282,
#  'stdF1set4_singleMI_p2_5XGBoost': 0.13520337708054253,
#  'n_singlevariancethres_p2_5XGBoost': 3,
#  'avgF1_singlevariancethres_p2_5XGBoost': 0.8139094058676102,
#  'stdF1_singlevariancethres_p2_5XGBoost': 0.07767029649821591,
#  'avgF1set1_singlevariancethres_p2_5XGBoost': 0.8442378338895367,
#  'stdF1set1_singlevariancethres_p2_5XGBoost': 0.046392444546284016,
#  'avgF1set2_singlevariancethres_p2_5XGBoost': 0.8379108645052918,
#  'stdF1set2_singlevariancethres_p2_5XGBoost': 0.07041073603086961,
#  'avgF1set3_singlevariancethres_p2_5XGBoost': 0.7996536796536796,
#  'stdF1set3_singlevariancethres_p2_5XGBoost': 0.02055142088233746,
#  'avgF1set4_singlevariancethres_p2_5XGBoost': 0.7530038898150353,
#  'stdF1set4_singlevariancethres_p2_5XGBoost': 0.10606435113452926,
#  'n_singleMultiSURF_p2_5XGBoost': 8,
#  'avgF1_singleMultiSURF_p2_5XGBoost': 0.8247795161494851,
#  'stdF1_singleMultiSURF_p2_5XGBoost': 0.05946904321894572,
#  'avgF1set1_singleMultiSURF_p2_5XGBoost': 0.8531203437085791,
#  'stdF1set1_singleMultiSURF_p2_5XGBoost': 0.07586466062966668,
#  'avgF1set2_singleMultiSURF_p2_5XGBoost': 0.8596562914209974,
#  'stdF1set2_singleMultiSURF_p2_5XGBoost': 0.07584922331214687,
#  'avgF1set3_singleMultiSURF_p2_5XGBoost': 0.7996536796536796,
#  'stdF1set3_singleMultiSURF_p2_5XGBoost': 0.02055142088233746,
#  'avgF1set4_singleMultiSURF_p2_5XGBoost': 0.840893665158371,
#  'stdF1set4_singleMultiSURF_p2_5XGBoost': 0.07517053653739426,
#  'n_singleMI_p5XGBoost': 16,
#  'avgF1_singleMI_p5XGBoost': 0.8829099804564201,
#  'stdF1_singleMI_p5XGBoost': 0.04915086654011707,
#  'avgF1set1_singleMI_p5XGBoost': 0.8976213818860878,
#  'stdF1set1_singleMI_p5XGBoost': 0.04797886164012967,
#  'avgF1set2_singleMI_p5XGBoost': 0.8910854341736695,
#  'stdF1set2_singleMI_p5XGBoost': 0.052920590624400646,
#  'avgF1set3_singleMI_p5XGBoost': 0.7996536796536796,
#  'stdF1set3_singleMI_p5XGBoost': 0.02055142088233746,
#  'avgF1set4_singleMI_p5XGBoost': 0.8891079508726568,
#  'stdF1set4_singleMI_p5XGBoost': 0.07840092548513558,
#  'n_singlevariancethres_p5XGBoost': 3,
#  'avgF1_singlevariancethres_p5XGBoost': 0.8139094058676102,
#  'stdF1_singlevariancethres_p5XGBoost': 0.07767029649821591,
#  'avgF1set1_singlevariancethres_p5XGBoost': 0.8442378338895367,
#  'stdF1set1_singlevariancethres_p5XGBoost': 0.046392444546284016,
#  'avgF1set2_singlevariancethres_p5XGBoost': 0.8379108645052918,
#  'stdF1set2_singlevariancethres_p5XGBoost': 0.07041073603086961,
#  'avgF1set3_singlevariancethres_p5XGBoost': 0.7996536796536796,
#  'stdF1set3_singlevariancethres_p5XGBoost': 0.02055142088233746,
#  'avgF1set4_singlevariancethres_p5XGBoost': 0.7530038898150353,
#  'stdF1set4_singlevariancethres_p5XGBoost': 0.10606435113452926,
#  'n_singleMultiSURF_p5XGBoost': 16,
#  'avgF1_singleMultiSURF_p5XGBoost': 0.843314422935166,
#  'stdF1_singleMultiSURF_p5XGBoost': 0.059078130836167225,
#  'avgF1set1_singleMultiSURF_p5XGBoost': 0.876109769143825,
#  'stdF1set1_singleMultiSURF_p5XGBoost': 0.0801557078886233,
#  'avgF1set2_singleMultiSURF_p5XGBoost': 0.8561807800043095,
#  'stdF1set2_singleMultiSURF_p5XGBoost': 0.06775258788354803,
#  'avgF1set3_singleMultiSURF_p5XGBoost': 0.7996536796536796,
#  'stdF1set3_singleMultiSURF_p5XGBoost': 0.02055142088233746,
#  'avgF1set4_singleMultiSURF_p5XGBoost': 0.8841656838173867,
#  'stdF1set4_singleMultiSURF_p5XGBoost': 0.06217591537574651,
#  'n_singleMI_p10XGBoost': 31,
#  'avgF1_singleMI_p10XGBoost': 0.8849340691987753,
#  'stdF1_singleMI_p10XGBoost': 0.0639748422267118,
#  'avgF1set1_singleMI_p10XGBoost': 0.8810854341736694,
#  'stdF1set1_singleMI_p10XGBoost': 0.05934894772031591,
#  'avgF1set2_singleMI_p10XGBoost': 0.9043650793650795,
#  'stdF1set2_singleMI_p10XGBoost': 0.052729719138482824,
#  'avgF1set3_singleMI_p10XGBoost': 0.7996536796536796,
#  'stdF1set3_singleMI_p10XGBoost': 0.02055142088233746,
#  'avgF1set4_singleMI_p10XGBoost': 0.8990873015873018,
#  'stdF1set4_singleMI_p10XGBoost': 0.04312309091446992,
#  'n_singlevariancethres_p10XGBoost': 3,
#  'avgF1_singlevariancethres_p10XGBoost': 0.8139094058676102,
#  'stdF1_singlevariancethres_p10XGBoost': 0.07767029649821591,
#  'avgF1set1_singlevariancethres_p10XGBoost': 0.8442378338895367,
#  'stdF1set1_singlevariancethres_p10XGBoost': 0.046392444546284016,
#  'avgF1set2_singlevariancethres_p10XGBoost': 0.8379108645052918,
#  'stdF1set2_singlevariancethres_p10XGBoost': 0.07041073603086961,
#  'avgF1set3_singlevariancethres_p10XGBoost': 0.7996536796536796,
#  'stdF1set3_singlevariancethres_p10XGBoost': 0.02055142088233746,
#  'avgF1set4_singlevariancethres_p10XGBoost': 0.7530038898150353,
#  'stdF1set4_singlevariancethres_p10XGBoost': 0.10606435113452926,
#  'n_singleMultiSURF_p10XGBoost': 31,
#  'avgF1_singleMultiSURF_p10XGBoost': 0.841358666273527,
#  'stdF1_singleMultiSURF_p10XGBoost': 0.07039779517394382,
#  'avgF1set1_singleMultiSURF_p10XGBoost': 0.8836969875669567,
#  'stdF1set1_singleMultiSURF_p10XGBoost': 0.06364135854542131,
#  'avgF1set2_singleMultiSURF_p10XGBoost': 0.8556435540723466,
#  'stdF1set2_singleMultiSURF_p10XGBoost': 0.04912067165729662,
#  'avgF1set3_singleMultiSURF_p10XGBoost': 0.7996536796536796,
#  'stdF1set3_singleMultiSURF_p10XGBoost': 0.02055142088233746,
#  'avgF1set4_singleMultiSURF_p10XGBoost': 0.8497750598214996,
#  'stdF1set4_singleMultiSURF_p10XGBoost': 0.07468379559357011,
#  'n_singleMI_p20XGBoost': 63,
#  'avgF1_singleMI_p20XGBoost': 0.8596301230589155,
#  'stdF1_singleMI_p20XGBoost': 0.045295527101393285,
#  'avgF1set1_singleMI_p20XGBoost': 0.8727453532020094,
#  'stdF1set1_singleMI_p20XGBoost': 0.055422725724415096,
#  'avgF1set2_singleMI_p20XGBoost': 0.88921802054155,
#  'stdF1set2_singleMI_p20XGBoost': 0.046962764013093114,
#  'avgF1set3_singleMI_p20XGBoost': 0.7996536796536796,
#  'stdF1set3_singleMI_p20XGBoost': 0.02055142088233746,
#  'avgF1set4_singleMI_p20XGBoost': 0.8883026287438053,
#  'stdF1set4_singleMI_p20XGBoost': 0.08083154644190214,
#  'n_singlevariancethres_p20XGBoost': 37,
#  'avgF1_singlevariancethres_p20XGBoost': 0.86422096908939,
#  'stdF1_singlevariancethres_p20XGBoost': 0.0621180530796776,
#  'avgF1set1_singlevariancethres_p20XGBoost': 0.8627550493881764,
#  'stdF1set1_singlevariancethres_p20XGBoost': 0.06479814985969269,
#  'avgF1set2_singlevariancethres_p20XGBoost': 0.8502049240748931,
#  'stdF1set2_singlevariancethres_p20XGBoost': 0.08442805409399907,
#  'avgF1set3_singlevariancethres_p20XGBoost': 0.7996536796536796,
#  'stdF1set3_singlevariancethres_p20XGBoost': 0.02055142088233746,
#  'avgF1set4_singlevariancethres_p20XGBoost': 0.8605695611577964,
#  'stdF1set4_singlevariancethres_p20XGBoost': 0.039132855700745546,
#  'n_singleMultiSURF_p20XGBoost': 63,
#  'avgF1_singleMultiSURF_p20XGBoost': 0.8221908939014202,
#  'stdF1_singleMultiSURF_p20XGBoost': 0.09256925359852387,
#  'avgF1set1_singleMultiSURF_p20XGBoost': 0.8254351659692217,
#  'stdF1set1_singleMultiSURF_p20XGBoost': 0.05403326710301302,
#  'avgF1set2_singleMultiSURF_p20XGBoost': 0.8516311612364242,
#  'stdF1set2_singleMultiSURF_p20XGBoost': 0.07670624002160999,
#  'avgF1set3_singleMultiSURF_p20XGBoost': 0.7996536796536796,
#  'stdF1set3_singleMultiSURF_p20XGBoost': 0.02055142088233746,
#  'avgF1set4_singleMultiSURF_p20XGBoost': 0.85438453359506,
#  'stdF1set4_singleMultiSURF_p20XGBoost': 0.07309259049170103}

# %%
output_single_Filter_XGBoost = pd.DataFrame([output_filter])
output_single_Filter_XGBoost = output_single_Filter_XGBoost.transpose()
output_single_Filter_XGBoost.to_csv('output_single_Filter_XGBoost.csv', index=True)

# %% [markdown]
# # Wrapper

# %%
SHAP_XGBoostfeatures = pd.read_csv('SHAP_XGBoostfeatures.csv')
rfe_XGBoostfeatures = pd.read_csv('rfe_XGBoostfeatures.csv')
boruta_XGBoostfeatures = pd.read_csv('boruta_XGBoostfeatures.csv')

# %%
method_Wrapper = {  'SHAP':SHAP_XGBoostfeatures,
                    'rfe': rfe_XGBoostfeatures,
                    'boruta': boruta_XGBoostfeatures
                }

# %%
output_wrapper = dict()


for tres,t in thres_d.items():
    for met,m in method_Wrapper.items():
        k =(filter_arr(m.filter(regex='value').squeeze(), t-1))   
        if k[1] != 0:
            n = k[1]+1 
            print("n"+"_single"+met+"_"+tres+"XGBoost",n)
            output_wrapper["n"+"_single"+met+"_"+tres+"XGBoost"] = n
            df_selected = m.iloc[:k[1]+1]
            df_filter = df1.filter(items=df_selected['Feature'])
            X = df_filter
            y = df1['class']
            
            ## before tuned ##
            xgbc = XGBClassifier(random_state=123)
            xgbc.fit(X,y)
            ## results F1 and stdF1 ##
            m = cross_val_score(xgbc, X, y, scoring="f1", cv = 10).mean() 
            s = cross_val_score(xgbc, X, y, scoring="f1", cv = 10).std() 
            print("avgF1"+"_single"+met+"_"+tres+"XGBoost" , m)
            print("stdF1"+"_single"+met+"_"+tres+"XGBoost",s)
            output_wrapper["avgF1"+"_single"+met+"_"+tres+"XGBoost"] = m
            output_wrapper["stdF1"+"_single"+met+"_"+tres+"XGBoost"] = s
            
            for parm, p in param_d.items():
                # Instantiate the grid search model
                grid_search = GridSearchCV(estimator = xgbc, param_grid = p,
                                        cv = 5, n_jobs = -1, verbose = 2,scoring='f1')
                # Fit the grid search to the data
                grid_search.fit(X,y)
        #         print(grid_search.best_params_)
                xgbc_tuned = XGBClassifier(subsample=grid_search.best_params_['subsample'],
                                                max_depth=grid_search.best_params_['max_depth'],
                                                colsample_bytree=grid_search.best_params_['colsample_bytree'],
                                                min_child_weight=grid_search.best_params_['min_child_weight'],
                                                learning_rate=grid_search.best_params_['learning_rate'],
                                                eta=grid_search.best_params_['eta'])
                xgbc_tuned.fit(X,y)

                ## results F1 and stdF1 ##
                m_tune  = cross_val_score(xgbc_tuned, X, y, scoring="f1", cv = 10).mean() 
                s_tune  = cross_val_score(xgbc_tuned, X, y, scoring="f1", cv = 10).std() 
                print("avgF1"+parm+"_single"+met+"_"+tres+"XGBoost" , m_tune)
                print("stdF1"+parm+"_single"+met+"_"+tres+"XGBoost",s_tune)
                output_wrapper["avgF1"+parm+"_single"+met+"_"+tres+"XGBoost"] = m_tune
                output_wrapper["stdF1"+parm+"_single"+met+"_"+tres+"XGBoost"] = s_tune

        else:
            output_wrapper["n"+"_single"+met+"_"+tres+"XGBoost"] = k[1]
            output_wrapper["avgF1"+"_single"+met+"_"+tres+"XGBoost"] = k[1]
            output_wrapper["stdF1"+"_single"+met+"_"+tres+"XGBoost"] = k[1]
            for parm, p in param_d.items():
                output_wrapper["avgF1"+parm+"_single"+met+"_"+tres+"XGBoost"] = k[1]
                output_wrapper["stdF1"+parm+"_single"+met+"_"+tres+"XGBoost"] = k[1]
# Out:
# n_singleSHAP_base2nXGBoost 7
# avgF1_singleSHAP_base2nXGBoost 0.9203479286451423
# stdF1_singleSHAP_base2nXGBoost 0.044146955569844305
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleSHAP_base2nXGBoost 0.9003186888790605
# stdF1set1_singleSHAP_base2nXGBoost 0.05253382766289704
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleSHAP_base2nXGBoost 0.9119007076514816
# stdF1set2_singleSHAP_base2nXGBoost 0.04303135105353047
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleSHAP_base2nXGBoost 0.7996536796536796
# stdF1set3_singleSHAP_base2nXGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleSHAP_base2nXGBoost 0.9194707356626862
# stdF1set4_singleSHAP_base2nXGBoost 0.027564712853517293
# n_singlerfe_base2nXGBoost 7
# avgF1_singlerfe_base2nXGBoost 0.8978527294858566
# stdF1_singlerfe_base2nXGBoost 0.06221018551553827
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singlerfe_base2nXGBoost 0.8978527294858566
# stdF1set1_singlerfe_base2nXGBoost 0.06221018551553827
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singlerfe_base2nXGBoost 0.904704776647501
# stdF1set2_singlerfe_base2nXGBoost 0.05444276242063975
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singlerfe_base2nXGBoost 0.7996536796536796
# stdF1set3_singlerfe_base2nXGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singlerfe_base2nXGBoost 0.9184430438842204
# stdF1set4_singlerfe_base2nXGBoost 0.04702531492524702
# n_singleSHAP_p2_5XGBoost 8
# avgF1_singleSHAP_p2_5XGBoost 0.9320197552705294
# stdF1_singleSHAP_p2_5XGBoost 0.04281351340683197
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleSHAP_p2_5XGBoost 0.915185021376972
# stdF1set1_singleSHAP_p2_5XGBoost 0.033045597847697096
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleSHAP_p2_5XGBoost 0.9150262912182419
# stdF1set2_singleSHAP_p2_5XGBoost 0.053763302070677664
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleSHAP_p2_5XGBoost 0.7996536796536796
# stdF1set3_singleSHAP_p2_5XGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleSHAP_p2_5XGBoost 0.915185021376972
# stdF1set4_singleSHAP_p2_5XGBoost 0.033045597847697096
# n_singlerfe_p2_5XGBoost 8
# avgF1_singlerfe_p2_5XGBoost 0.9007820224151495
# stdF1_singlerfe_p2_5XGBoost 0.07437191810133555
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singlerfe_p2_5XGBoost 0.9001610644257703
# stdF1set1_singlerfe_p2_5XGBoost 0.0605194539501841
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singlerfe_p2_5XGBoost 0.9089638405969677
# stdF1set2_singlerfe_p2_5XGBoost 0.06915216435715088
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singlerfe_p2_5XGBoost 0.7996536796536796
# stdF1set3_singlerfe_p2_5XGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singlerfe_p2_5XGBoost 0.91171802054155
# stdF1set4_singlerfe_p2_5XGBoost 0.0642023385818595
# n_singleSHAP_p5XGBoost 16
# avgF1_singleSHAP_p5XGBoost 0.9024020836404738
# stdF1_singleSHAP_p5XGBoost 0.053944664985644486
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleSHAP_p5XGBoost 0.8985154061624648
# stdF1set1_singleSHAP_p5XGBoost 0.06277410918948528
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleSHAP_p5XGBoost 0.9138795518207283
# stdF1set2_singleSHAP_p5XGBoost 0.07553387494464137
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleSHAP_p5XGBoost 0.7996536796536796
# stdF1set3_singleSHAP_p5XGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleSHAP_p5XGBoost 0.9372421249201436
# stdF1set4_singleSHAP_p5XGBoost 0.05217405002437183
# n_singlerfe_p5XGBoost 16
# avgF1_singlerfe_p5XGBoost 0.8917011892476288
# stdF1_singlerfe_p5XGBoost 0.03335596629586371
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singlerfe_p5XGBoost 0.9076493930905697
# stdF1set1_singlerfe_p5XGBoost 0.05231541881254454
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singlerfe_p5XGBoost 0.8946683218742042
# stdF1set2_singlerfe_p5XGBoost 0.05572995763840836
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singlerfe_p5XGBoost 0.7996536796536796
# stdF1set3_singlerfe_p5XGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singlerfe_p5XGBoost 0.9213379370887111
# stdF1set4_singlerfe_p5XGBoost 0.055989959691207875
# n_singleboruta_p5XGBoost 12
# avgF1_singleboruta_p5XGBoost 0.8836017740429505
# stdF1_singleboruta_p5XGBoost 0.05305716915254722
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleboruta_p5XGBoost 0.9100396825396826
# stdF1set1_singleboruta_p5XGBoost 0.04964729783597197
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleboruta_p5XGBoost 0.8824889429455993
# stdF1set2_singleboruta_p5XGBoost 0.06071809365366912
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleboruta_p5XGBoost 0.7996536796536796
# stdF1set3_singleboruta_p5XGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleboruta_p5XGBoost 0.9042880485527546
# stdF1set4_singleboruta_p5XGBoost 0.056374910349486565
# n_singleSHAP_p10XGBoost 31
# avgF1_singleSHAP_p10XGBoost 0.8664841024128951
# stdF1_singleSHAP_p10XGBoost 0.05446546905604167
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleSHAP_p10XGBoost 0.903212353521951
# stdF1set1_singleSHAP_p10XGBoost 0.05055866478336774
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleSHAP_p10XGBoost 0.9043234646330622
# stdF1set2_singleSHAP_p10XGBoost 0.05035334918733068
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleSHAP_p10XGBoost 0.7996536796536796
# stdF1set3_singleSHAP_p10XGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleSHAP_p10XGBoost 0.9229908103592315
# stdF1set4_singleSHAP_p10XGBoost 0.058160315057837045
# n_singlerfe_p10XGBoost 31
# avgF1_singlerfe_p10XGBoost 0.9024352548036759
# stdF1_singlerfe_p10XGBoost 0.04614146264197688
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singlerfe_p10XGBoost 0.8845002546473134
# stdF1set1_singlerfe_p10XGBoost 0.06575227048467555
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singlerfe_p10XGBoost 0.9065947064631276
# stdF1set2_singlerfe_p10XGBoost 0.05844619297680341
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singlerfe_p10XGBoost 0.7996536796536796
# stdF1set3_singlerfe_p10XGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singlerfe_p10XGBoost 0.8845002546473134
# stdF1set4_singlerfe_p10XGBoost 0.06575227048467555
# n_singleboruta_p10XGBoost 31
# avgF1_singleboruta_p10XGBoost 0.8959755114166879
# stdF1_singleboruta_p10XGBoost 0.04887151072115319
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleboruta_p10XGBoost 0.8894395637042696
# stdF1set1_singleboruta_p10XGBoost 0.05353062358371761
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleboruta_p10XGBoost 0.8908430724761993
# stdF1set2_singleboruta_p10XGBoost 0.0548312572765985
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleboruta_p10XGBoost 0.7996536796536796
# stdF1set3_singleboruta_p10XGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleboruta_p10XGBoost 0.890954715219421
# stdF1set4_singleboruta_p10XGBoost 0.03656395660707244
# n_singleSHAP_p20XGBoost 62
# avgF1_singleSHAP_p20XGBoost 0.8818205160852219
# stdF1_singleSHAP_p20XGBoost 0.05214517426269486
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleSHAP_p20XGBoost 0.8898249299719888
# stdF1set1_singleSHAP_p20XGBoost 0.08001808883101999
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleSHAP_p20XGBoost 0.9054409642644936
# stdF1set2_singleSHAP_p20XGBoost 0.06035589327152174
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleSHAP_p20XGBoost 0.7996536796536796
# stdF1set3_singleSHAP_p20XGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleSHAP_p20XGBoost 0.905109710550887
# stdF1set4_singleSHAP_p20XGBoost 0.058432061905335696
# n_singlerfe_p20XGBoost 63
# avgF1_singlerfe_p20XGBoost 0.853993359581595
# stdF1_singlerfe_p20XGBoost 0.04576370812564014
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singlerfe_p20XGBoost 0.9085245310245311
# stdF1set1_singlerfe_p20XGBoost 0.06364976162732519
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singlerfe_p20XGBoost 0.9018088447500213
# stdF1set2_singlerfe_p20XGBoost 0.04949707324990472
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singlerfe_p20XGBoost 0.7996536796536796
# stdF1set3_singlerfe_p20XGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singlerfe_p20XGBoost 0.8955859010270775
# stdF1set4_singlerfe_p20XGBoost 0.04564057679252585
# n_singleboruta_p20XGBoost 63
# avgF1_singleboruta_p20XGBoost 0.8918578643578643
# stdF1_singleboruta_p20XGBoost 0.046570124787246224
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleboruta_p20XGBoost 0.9102268259776001
# stdF1set1_singleboruta_p20XGBoost 0.049979404306785276
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleboruta_p20XGBoost 0.9046931053123004
# stdF1set2_singleboruta_p20XGBoost 0.04865946373689684
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleboruta_p20XGBoost 0.7996536796536796
# stdF1set3_singleboruta_p20XGBoost 0.02055142088233746
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleboruta_p20XGBoost 0.895321916645446
# stdF1set4_singleboruta_p20XGBoost 0.06152735846056865

# %%
output_wrapper
# Out:
# {'n_singleSHAP_base2nXGBoost': 7,
#  'avgF1_singleSHAP_base2nXGBoost': 0.9203479286451423,
#  'stdF1_singleSHAP_base2nXGBoost': 0.044146955569844305,
#  'avgF1set1_singleSHAP_base2nXGBoost': 0.9003186888790605,
#  'stdF1set1_singleSHAP_base2nXGBoost': 0.05253382766289704,
#  'avgF1set2_singleSHAP_base2nXGBoost': 0.9119007076514816,
#  'stdF1set2_singleSHAP_base2nXGBoost': 0.04303135105353047,
#  'avgF1set3_singleSHAP_base2nXGBoost': 0.7996536796536796,
#  'stdF1set3_singleSHAP_base2nXGBoost': 0.02055142088233746,
#  'avgF1set4_singleSHAP_base2nXGBoost': 0.9194707356626862,
#  'stdF1set4_singleSHAP_base2nXGBoost': 0.027564712853517293,
#  'n_singlerfe_base2nXGBoost': 7,
#  'avgF1_singlerfe_base2nXGBoost': 0.8978527294858566,
#  'stdF1_singlerfe_base2nXGBoost': 0.06221018551553827,
#  'avgF1set1_singlerfe_base2nXGBoost': 0.8978527294858566,
#  'stdF1set1_singlerfe_base2nXGBoost': 0.06221018551553827,
#  'avgF1set2_singlerfe_base2nXGBoost': 0.904704776647501,
#  'stdF1set2_singlerfe_base2nXGBoost': 0.05444276242063975,
#  'avgF1set3_singlerfe_base2nXGBoost': 0.7996536796536796,
#  'stdF1set3_singlerfe_base2nXGBoost': 0.02055142088233746,
#  'avgF1set4_singlerfe_base2nXGBoost': 0.9184430438842204,
#  'stdF1set4_singlerfe_base2nXGBoost': 0.04702531492524702,
#  'n_singleboruta_base2nXGBoost': 0,
#  'avgF1_singleboruta_base2nXGBoost': 0,
#  'stdF1_singleboruta_base2nXGBoost': 0,
#  'avgF1set1_singleboruta_base2nXGBoost': 0,
#  'stdF1set1_singleboruta_base2nXGBoost': 0,
#  'avgF1set2_singleboruta_base2nXGBoost': 0,
#  'stdF1set2_singleboruta_base2nXGBoost': 0,
#  'avgF1set3_singleboruta_base2nXGBoost': 0,
#  'stdF1set3_singleboruta_base2nXGBoost': 0,
#  'avgF1set4_singleboruta_base2nXGBoost': 0,
#  'stdF1set4_singleboruta_base2nXGBoost': 0,
#  'n_singleSHAP_p2_5XGBoost': 8,
#  'avgF1_singleSHAP_p2_5XGBoost': 0.9320197552705294,
#  'stdF1_singleSHAP_p2_5XGBoost': 0.04281351340683197,
#  'avgF1set1_singleSHAP_p2_5XGBoost': 0.915185021376972,
#  'stdF1set1_singleSHAP_p2_5XGBoost': 0.033045597847697096,
#  'avgF1set2_singleSHAP_p2_5XGBoost': 0.9150262912182419,
#  'stdF1set2_singleSHAP_p2_5XGBoost': 0.053763302070677664,
#  'avgF1set3_singleSHAP_p2_5XGBoost': 0.7996536796536796,
#  'stdF1set3_singleSHAP_p2_5XGBoost': 0.02055142088233746,
#  'avgF1set4_singleSHAP_p2_5XGBoost': 0.915185021376972,
#  'stdF1set4_singleSHAP_p2_5XGBoost': 0.033045597847697096,
#  'n_singlerfe_p2_5XGBoost': 8,
#  'avgF1_singlerfe_p2_5XGBoost': 0.9007820224151495,
#  'stdF1_singlerfe_p2_5XGBoost': 0.07437191810133555,
#  'avgF1set1_singlerfe_p2_5XGBoost': 0.9001610644257703,
#  'stdF1set1_singlerfe_p2_5XGBoost': 0.0605194539501841,
#  'avgF1set2_singlerfe_p2_5XGBoost': 0.9089638405969677,
#  'stdF1set2_singlerfe_p2_5XGBoost': 0.06915216435715088,
#  'avgF1set3_singlerfe_p2_5XGBoost': 0.7996536796536796,
#  'stdF1set3_singlerfe_p2_5XGBoost': 0.02055142088233746,
#  'avgF1set4_singlerfe_p2_5XGBoost': 0.91171802054155,
#  'stdF1set4_singlerfe_p2_5XGBoost': 0.0642023385818595,
#  'n_singleboruta_p2_5XGBoost': 0,
#  'avgF1_singleboruta_p2_5XGBoost': 0,
#  'stdF1_singleboruta_p2_5XGBoost': 0,
#  'avgF1set1_singleboruta_p2_5XGBoost': 0,
#  'stdF1set1_singleboruta_p2_5XGBoost': 0,
#  'avgF1set2_singleboruta_p2_5XGBoost': 0,
#  'stdF1set2_singleboruta_p2_5XGBoost': 0,
#  'avgF1set3_singleboruta_p2_5XGBoost': 0,
#  'stdF1set3_singleboruta_p2_5XGBoost': 0,
#  'avgF1set4_singleboruta_p2_5XGBoost': 0,
#  'stdF1set4_singleboruta_p2_5XGBoost': 0,
#  'n_singleSHAP_p5XGBoost': 16,
#  'avgF1_singleSHAP_p5XGBoost': 0.9024020836404738,
#  'stdF1_singleSHAP_p5XGBoost': 0.053944664985644486,
#  'avgF1set1_singleSHAP_p5XGBoost': 0.8985154061624648,
#  'stdF1set1_singleSHAP_p5XGBoost': 0.06277410918948528,
#  'avgF1set2_singleSHAP_p5XGBoost': 0.9138795518207283,
#  'stdF1set2_singleSHAP_p5XGBoost': 0.07553387494464137,
#  'avgF1set3_singleSHAP_p5XGBoost': 0.7996536796536796,
#  'stdF1set3_singleSHAP_p5XGBoost': 0.02055142088233746,
#  'avgF1set4_singleSHAP_p5XGBoost': 0.9372421249201436,
#  'stdF1set4_singleSHAP_p5XGBoost': 0.05217405002437183,
#  'n_singlerfe_p5XGBoost': 16,
#  'avgF1_singlerfe_p5XGBoost': 0.8917011892476288,
#  'stdF1_singlerfe_p5XGBoost': 0.03335596629586371,
#  'avgF1set1_singlerfe_p5XGBoost': 0.9076493930905697,
#  'stdF1set1_singlerfe_p5XGBoost': 0.05231541881254454,
#  'avgF1set2_singlerfe_p5XGBoost': 0.8946683218742042,
#  'stdF1set2_singlerfe_p5XGBoost': 0.05572995763840836,
#  'avgF1set3_singlerfe_p5XGBoost': 0.7996536796536796,
#  'stdF1set3_singlerfe_p5XGBoost': 0.02055142088233746,
#  'avgF1set4_singlerfe_p5XGBoost': 0.9213379370887111,
#  'stdF1set4_singlerfe_p5XGBoost': 0.055989959691207875,
#  'n_singleboruta_p5XGBoost': 12,
#  'avgF1_singleboruta_p5XGBoost': 0.8836017740429505,
#  'stdF1_singleboruta_p5XGBoost': 0.05305716915254722,
#  'avgF1set1_singleboruta_p5XGBoost': 0.9100396825396826,
#  'stdF1set1_singleboruta_p5XGBoost': 0.04964729783597197,
#  'avgF1set2_singleboruta_p5XGBoost': 0.8824889429455993,
#  'stdF1set2_singleboruta_p5XGBoost': 0.06071809365366912,
#  'avgF1set3_singleboruta_p5XGBoost': 0.7996536796536796,
#  'stdF1set3_singleboruta_p5XGBoost': 0.02055142088233746,
#  'avgF1set4_singleboruta_p5XGBoost': 0.9042880485527546,
#  'stdF1set4_singleboruta_p5XGBoost': 0.056374910349486565,
#  'n_singleSHAP_p10XGBoost': 31,
#  'avgF1_singleSHAP_p10XGBoost': 0.8664841024128951,
#  'stdF1_singleSHAP_p10XGBoost': 0.05446546905604167,
#  'avgF1set1_singleSHAP_p10XGBoost': 0.903212353521951,
#  'stdF1set1_singleSHAP_p10XGBoost': 0.05055866478336774,
#  'avgF1set2_singleSHAP_p10XGBoost': 0.9043234646330622,
#  'stdF1set2_singleSHAP_p10XGBoost': 0.05035334918733068,
#  'avgF1set3_singleSHAP_p10XGBoost': 0.7996536796536796,
#  'stdF1set3_singleSHAP_p10XGBoost': 0.02055142088233746,
#  'avgF1set4_singleSHAP_p10XGBoost': 0.9229908103592315,
#  'stdF1set4_singleSHAP_p10XGBoost': 0.058160315057837045,
#  'n_singlerfe_p10XGBoost': 31,
#  'avgF1_singlerfe_p10XGBoost': 0.9024352548036759,
#  'stdF1_singlerfe_p10XGBoost': 0.04614146264197688,
#  'avgF1set1_singlerfe_p10XGBoost': 0.8845002546473134,
#  'stdF1set1_singlerfe_p10XGBoost': 0.06575227048467555,
#  'avgF1set2_singlerfe_p10XGBoost': 0.9065947064631276,
#  'stdF1set2_singlerfe_p10XGBoost': 0.05844619297680341,
#  'avgF1set3_singlerfe_p10XGBoost': 0.7996536796536796,
#  'stdF1set3_singlerfe_p10XGBoost': 0.02055142088233746,
#  'avgF1set4_singlerfe_p10XGBoost': 0.8845002546473134,
#  'stdF1set4_singlerfe_p10XGBoost': 0.06575227048467555,
#  'n_singleboruta_p10XGBoost': 31,
#  'avgF1_singleboruta_p10XGBoost': 0.8959755114166879,
#  'stdF1_singleboruta_p10XGBoost': 0.04887151072115319,
#  'avgF1set1_singleboruta_p10XGBoost': 0.8894395637042696,
#  'stdF1set1_singleboruta_p10XGBoost': 0.05353062358371761,
#  'avgF1set2_singleboruta_p10XGBoost': 0.8908430724761993,
#  'stdF1set2_singleboruta_p10XGBoost': 0.0548312572765985,
#  'avgF1set3_singleboruta_p10XGBoost': 0.7996536796536796,
#  'stdF1set3_singleboruta_p10XGBoost': 0.02055142088233746,
#  'avgF1set4_singleboruta_p10XGBoost': 0.890954715219421,
#  'stdF1set4_singleboruta_p10XGBoost': 0.03656395660707244,
#  'n_singleSHAP_p20XGBoost': 62,
#  'avgF1_singleSHAP_p20XGBoost': 0.8818205160852219,
#  'stdF1_singleSHAP_p20XGBoost': 0.05214517426269486,
#  'avgF1set1_singleSHAP_p20XGBoost': 0.8898249299719888,
#  'stdF1set1_singleSHAP_p20XGBoost': 0.08001808883101999,
#  'avgF1set2_singleSHAP_p20XGBoost': 0.9054409642644936,
#  'stdF1set2_singleSHAP_p20XGBoost': 0.06035589327152174,
#  'avgF1set3_singleSHAP_p20XGBoost': 0.7996536796536796,
#  'stdF1set3_singleSHAP_p20XGBoost': 0.02055142088233746,
#  'avgF1set4_singleSHAP_p20XGBoost': 0.905109710550887,
#  'stdF1set4_singleSHAP_p20XGBoost': 0.058432061905335696,
#  'n_singlerfe_p20XGBoost': 63,
#  'avgF1_singlerfe_p20XGBoost': 0.853993359581595,
#  'stdF1_singlerfe_p20XGBoost': 0.04576370812564014,
#  'avgF1set1_singlerfe_p20XGBoost': 0.9085245310245311,
#  'stdF1set1_singlerfe_p20XGBoost': 0.06364976162732519,
#  'avgF1set2_singlerfe_p20XGBoost': 0.9018088447500213,
#  'stdF1set2_singlerfe_p20XGBoost': 0.04949707324990472,
#  'avgF1set3_singlerfe_p20XGBoost': 0.7996536796536796,
#  'stdF1set3_singlerfe_p20XGBoost': 0.02055142088233746,
#  'avgF1set4_singlerfe_p20XGBoost': 0.8955859010270775,
#  'stdF1set4_singlerfe_p20XGBoost': 0.04564057679252585,
#  'n_singleboruta_p20XGBoost': 63,
#  'avgF1_singleboruta_p20XGBoost': 0.8918578643578643,
#  'stdF1_singleboruta_p20XGBoost': 0.046570124787246224,
#  'avgF1set1_singleboruta_p20XGBoost': 0.9102268259776001,
#  'stdF1set1_singleboruta_p20XGBoost': 0.049979404306785276,
#  'avgF1set2_singleboruta_p20XGBoost': 0.9046931053123004,
#  'stdF1set2_singleboruta_p20XGBoost': 0.04865946373689684,
#  'avgF1set3_singleboruta_p20XGBoost': 0.7996536796536796,
#  'stdF1set3_singleboruta_p20XGBoost': 0.02055142088233746,
#  'avgF1set4_singleboruta_p20XGBoost': 0.895321916645446,
#  'stdF1set4_singleboruta_p20XGBoost': 0.06152735846056865}

# %%
output_single_wrapper_XGBoost = pd.DataFrame([output_wrapper])
output_single_wrapper_XGBoost = output_single_wrapper_XGBoost.transpose()
output_single_wrapper_XGBoost.to_csv('output_single_wrapper_XGBoost.csv', index=True)
